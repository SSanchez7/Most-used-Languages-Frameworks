# %%
import pandas as pd
import numpy as np
import os
import bar_chart_race as bcr
import ffmpeg
import matplotlib as mt

# %%
path = 'TagByDate2'
listDir = os.listdir(path)
tagBDF = pd.DataFrame()
for direc in listDir:
    df = pd.read_csv(os.path.join(path, direc), names=['date','tag','count'])
    tagBDF = pd.concat([tagBDF, df], axis=0)

# %%
tagBDF
# Out:
#            date         tag count
# 0    2013-12-21  javascript   106
# 1    2016-06-14         c++    66
# 2    2010-05-20       mysql     6
# 3    2009-11-24     android     5
# 4    2011-02-09         css    37
# ..          ...         ...   ...
# 532  2010-09-01        java    83
# 533  2011-10-08       mysql    21
# 534  2012-02-25  javascript    66
# 535  2014-02-13     android   148
# 536  2009-10-31         sql    20
#
# [43395 rows x 3 columns]

# %%
tagBDF.sort_values(by=['date'], inplace=True)
tagBDF.reset_index(drop=True, inplace=True)
tagBDF
# Out:
#              date         tag count
# 0      2008-08-01         sql     1
# 1      2008-08-01     asp.net     1
# 2      2008-08-01          c#     2
# 3      2008-08-02         c++     2
# 4      2008-08-02          c#     3
# ...           ...         ...   ...
# 43390  2016-10-19      python   182
# 43391  2016-10-19  javascript   217
# 43392  2016-10-19     android   139
# 43393  2016-10-19        java   182
# 43394  2016-10-19     asp.net    14
#
# [43395 rows x 3 columns]

# %%
tagBDF["count"] = pd.to_numeric(tagBDF["count"])

# %%
tagBDF.to_csv('tagBDF.csv', index=False)

# %%
tagBDF_ = tagBDF.pivot_table(index=['date'], columns='tag', values='count', fill_value=0)
tagBDF_
# Out:
# tag         android  asp.net   c   c#  c++  css  html  ios  java  javascript  \
# date
# 2008-08-01        0        1   0    2    0    0     0    0     0           0
# 2008-08-02        0        0   0    3    2    0     0    0     0           0
# 2008-08-03        0        0   0    3    0    0     0    0     0           0
# 2008-08-04        0        3   0   14    0    0     0    0     0           0
# 2008-08-05        0        5   3   13    2    0     6    0     0           0
# ...             ...      ...  ..  ...  ...  ...   ...  ...   ...         ...
# 2016-10-15       84        4  34   45   52   40    39   41   123         115
# 2016-10-16       60       15  29   59   28   29    45   40   101         105
# 2016-10-17      164       26  31  112   64   59   108   90   171         172
# 2016-10-18      163       41  37  141   69   67   103   75   199         255
# 2016-10-19      139       14  40  141   56   79   119   83   182         217
#
# tag         jquery  mysql  php  python  sql
# date
# 2008-08-01       0      0    0       0    1
# 2008-08-02       0      0    0       0    0
# 2008-08-03       0      0    0       0    0
# 2008-08-04       0      0    0       0    0
# 2008-08-05       0      5    5       0    7
# ...            ...    ...  ...     ...  ...
# 2016-10-15      44     43   62      88   29
# 2016-10-16      29     29   62     107   32
# 2016-10-17      70     23  116     152   38
# 2016-10-18      80     67  131     169   69
# 2016-10-19      92     64  152     182   48
#
# [3002 rows x 15 columns]

# %%
tagBDF_.index = pd.to_datetime(tagBDF_.index)
tagBDF_ = tagBDF_.resample('M').sum() #Agrupa por mes
tagBDF_
# Out:
# tag         android  asp.net    c    c#   c++   css  html   ios  java  \
# date
# 2008-08-31        2      112   68   233    96    48    42     0   112
# 2008-09-30        5      441  241   870   550   185   239     0   670
# 2008-10-31        0      400  233   848   420   112   197     5   468
# 2008-11-30        0      331  124   613   323    94   156     3   413
# 2008-12-31        4      336  124   697   406   139   164     2   371
# ...             ...      ...  ...   ...   ...   ...   ...   ...   ...
# 2016-06-30     3440      740  593  3377  1546  1876  2732  1872  4083
# 2016-07-31     3760      587  637  3035  1493  1863  2792  1783  3864
# 2016-08-31     3572      705  612  3235  1376  1990  2720  1819  4114
# 2016-09-30     3341      614  784  2914  1296  1726  2455  1861  4046
# 2016-10-31     2222      383  607  1859  1070  1138  1714  1265  2803
#
# tag         javascript  jquery  mysql   php  python   sql
# date
# 2008-08-31          70       7     32    66      40   106
# 2008-09-30         321      91    137   276     288   318
# 2008-10-31         354     116    109   269     285   263
# 2008-11-30         212      84    102   235     191   193
# 2008-12-31         261      86    137   218     204   207
# ...                ...     ...    ...   ...     ...   ...
# 2016-06-30        5902    2558   1476  3420    3433  1496
# 2016-07-31        5919    2556   1478  3402    3365  1275
# 2016-08-31        6024    2525   1441  3297    3259  1231
# 2016-09-30        5447    2224   1367  3110    3261  1276
# 2016-10-31        3435    1359    853  2130    2414   928
#
# [99 rows x 15 columns]

# %%
for c in tagBDF_.columns:
    tagBDF_[c] = tagBDF_[c].cumsum()
tagBDF_
# Out:
# tag         android  asp.net      c      c#     c++     css    html     ios  \
# date
# 2008-08-31        2      112     68     233      96      48      42       0
# 2008-09-30        7      553    309    1103     646     233     281       0
# 2008-10-31        7      953    542    1951    1066     345     478       5
# 2008-11-30        7     1284    666    2564    1389     439     634       8
# 2008-12-31       11     1620    790    3261    1795     578     798      10
# ...             ...      ...    ...     ...     ...     ...     ...     ...
# 2016-06-30   206718    77403  70617  270385  134618  115074  157916  107557
# 2016-07-31   210478    77990  71254  273420  136111  116937  160708  109340
# 2016-08-31   214050    78695  71866  276655  137487  118927  163428  111159
# 2016-09-30   217391    79309  72650  279569  138783  120653  165883  113020
# 2016-10-31   219613    79692  73257  281428  139853  121791  167597  114285
#
# tag           java  javascript  jquery   mysql     php  python     sql
# date
# 2008-08-31     112          70       7      32      66      40     106
# 2008-09-30     782         391      98     169     342     328     424
# 2008-10-31    1250         745     214     278     611     613     687
# 2008-11-30    1663         957     298     380     846     804     880
# 2008-12-31    2034        1218     384     517    1064    1008    1087
# ...            ...         ...     ...     ...     ...     ...     ...
# 2016-06-30  301258      308508  206863  109445  255011  157509   99670
# 2016-07-31  305122      314427  209419  110923  258413  160874  100945
# 2016-08-31  309236      320451  211944  112364  261710  164133  102176
# 2016-09-30  313282      325898  214168  113731  264820  167394  103452
# 2016-10-31  316085      329333  215527  114584  266950  169808  104380
#
# [99 rows x 15 columns]

# %%
import seaborn as sns
from matplotlib.colors import ListedColormap
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
my_cmap = ListedColormap(sns.color_palette(flatui).as_hex())

# %%
bcr.bar_chart_race(df=tagBDF_, 
                   filename="tagRaceF3.mp4", 
                   n_bars=10, 
                   title='Tags from 10% of Stack Overflow Q&A by frequency', 
                   period_fmt='%B %Y',
                   filter_column_colors=True,
                   cmap='my_cmap')#,
                   #period_length=50)

'''bcr.bar_chart_race(df=qtByDate_, filename=None,
    orientation='h',
    sort='desc',
    n_bars=6,
    fixed_order=False,
    fixed_max=True,
    steps_per_period=10,
    interpolate_period=False,
    label_bars=True,
    bar_size=.95,
    period_label={'x': .99, 'y': .25, 'ha': 'right', 'va': 'center'},
    period_fmt='%B %d, %Y',
    period_summary_func=lambda v, r: {'x': .99, 'y': .18,
                                      's': f'Total deaths: {v.nlargest(6).sum():,.0f}',
                                      'ha': 'right', 'size': 8, 'family': 'Courier New'},
    perpendicular_bar_func='median',
    period_length=500,
    figsize=(5, 3),
    dpi=144,
    cmap='dark12',
    title='COVID-19 Deaths by Country',
    title_size='',
    bar_label_size=7,
    tick_label_size=7,
    shared_fontdict={'family' : 'Helvetica', 'color' : '.1'},
    scale='linear',
    writer=None,
    fig=None,
    bar_kwargs={'alpha': .7},
    filter_column_colors=False)'''
# Out:
# c:\python39\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# c:\python39\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-c3a82530573f> in <module>
# ----> 1 bcr.bar_chart_race(df=tagBDF_,
#       2                    filename="tagRaceF3.mp4",
#       3                    n_bars=10,
#       4                    title='Tags from 10% of Stack Overflow Q&A by frequency',
#       5                    period_fmt='%B %Y',
#
# c:\python39\lib\site-packages\bar_chart_race\_make_chart.py in bar_chart_race(df, filename, orientation, sort, n_bars, fixed_order, fixed_max, steps_per_period, period_length, interpolate_period, label_bars, bar_size, period_label, period_fmt, period_summary_func, perpendicular_bar_func, figsize, cmap, title, title_size, bar_label_size, tick_label_size, shared_fontdict, scale, writer, fig, dpi, bar_kwargs, filter_column_colors)
#     781                         figsize, cmap, title, title_size, bar_label_size, tick_label_size,
#     782                         shared_fontdict, scale, writer, fig, dpi, bar_kwargs, filter_column_colors)
# --> 783     return bcr.make_animation()
#     784
#     785 def load_dataset(name='covid19'):
#
# c:\python39\lib\site-packages\bar_chart_race\_make_chart.py in make_animation(self)
#     433                     pass
#     434             else:
# --> 435                 ret_val = anim.save(self.filename, fps=self.fps, writer=self.writer)
#     436         except Exception as e:
#     437             if self.extension != 'gif':
#
# c:\python39\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1175                         progress_callback(frame_number, total_frames)
#    1176                         frame_number += 1
# -> 1177                 writer.grab_frame(**savefig_kwargs)
#    1178
#    1179     def _step(self, *args):
#
# c:\python39\lib\site-packages\matplotlib\animation.py in grab_frame(self, **savefig_kwargs)
#     354         self.fig.set_size_inches(self._w, self._h)
#     355         # Save the figure data to the sink, using the frame format and dpi.
# --> 356         self.fig.savefig(self._proc.stdin, format=self.frame_format,
#     357                          dpi=self.dpi, **savefig_kwargs)
#     358
#
# c:\python39\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    3003                 patch.set_edgecolor('none')
#    3004
# -> 3005         self.canvas.print_figure(fname, **kwargs)
#    3006
#    3007         if transparent:
#
# c:\python39\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# c:\python39\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# c:\python39\lib\site-packages\matplotlib\backends\backend_agg.py in print_raw(self, filename_or_obj, *args)
#     450     @_check_savefig_extra_args
#     451     def print_raw(self, filename_or_obj, *args):
# --> 452         FigureCanvasAgg.draw(self)
#     453         renderer = self.get_renderer()
#     454         with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#
# c:\python39\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     404              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     405               else nullcontext()):
# --> 406             self.figure.draw(self.renderer)
#     407             # A GUI class may be need to update a window using this draw, so
#     408             # don't forget to call the superclass.
#
# c:\python39\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# c:\python39\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# c:\python39\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2778
#    2779             self.patch.draw(renderer)
# -> 2780             mimage._draw_list_compositing_images(
#    2781                 renderer, self, artists, self.suppressComposite)
#    2782
#
# c:\python39\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# c:\python39\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# c:\python39\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# c:\python39\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2919             renderer.stop_rasterizing()
#    2920
# -> 2921         mimage._draw_list_compositing_images(renderer, self, artists)
#    2922
#    2923         renderer.close_group('axes')
#
# c:\python39\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# c:\python39\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# c:\python39\lib\site-packages\matplotlib\text.py in draw(self, renderer)
#     725                                           mtext=mtext)
#     726                 else:
# --> 727                     textrenderer.draw_text(gc, x, y, clean_line,
#     728                                            textobj._fontproperties, angle,
#     729                                            ismath=ismath, mtext=mtext)
#
# c:\python39\lib\site-packages\matplotlib\backends\backend_agg.py in draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#     201         # We pass '0' for angle here, since it will be rotated (in raster
#     202         # space) in the following call to draw_text_image).
# --> 203         font.set_text(s, 0, flags=flags)
#     204         font.draw_glyphs_to_bitmap(
#     205             antialiased=mpl.rcParams['text.antialiased'])
#
# KeyboardInterrupt:
